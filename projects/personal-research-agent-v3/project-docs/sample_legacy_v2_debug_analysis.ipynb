# %% [markdown]
# # Personal Research Agent Test Analysis: v2-[REDACTED_PHONE]

# %% [markdown]
# ## Introduction
#
# This notebook summarizes a Personal Research Agent debug run. It focuses on deterministic evidence: input request, validation counts, rejection reasons, selected categories, and output lengths.

# %% [markdown]
# ## Setup
#
# - Debug directory: `../personal-research-agent-v2/debug/20260422T133303Z__v2-20260422133303`
# - Regenerate this notebook with `python3 scripts/generate_test_notebook.py`.
# - Install project requirements before running the analysis code cells.

# %% [markdown]
# ## Data Overview
#
# Input request: Prepare my Personal Research Agent V2 digest with emphasis on Netherlands and Limburg news, family-friendly weekend events near Maastricht, and fresh Bitcoin market/technical/community signals.
#
# - Candidate count: 40
# - Valid count: 4
# - Rejected count: 36
# - Quality gate status: `warn`
# - Report length: 5427
# - Newsletter length: 1892
#
# ### Selected Counts
#
# | Item | Count |
# | --- | ---: |
# | bitcoin | 1 |
# | events | 1 |
# | news | 1 |
#
# ### Rejection Reasons
#
# | Item | Count |
# | --- | ---: |
# | altcoin_noise | 1 |
# | duplicate_in_run | 5 |
# | generic_listing | 7 |
# | low_trust_source | 3 |
# | missing_specific_date | 2 |
# | not_article_page | 5 |
# | not_recent | 13 |

# %% [markdown]
# ## Artifact Warnings
#
# - No missing or invalid debug artifacts detected.

# %%
import json
from pathlib import Path

DEBUG_DIR = Path('../personal-research-agent-v2/debug/20260422T133303Z__v2-20260422133303')
artifacts = {}
for path in sorted(DEBUG_DIR.glob('*.json')):
    with path.open('r', encoding='utf-8') as handle:
        artifacts[path.name] = json.load(handle)
sorted(artifacts)

# %% [markdown]
# ## Analysis
#
# The next cells convert validation previews into tables and plot compact distributions. Large candidate lists should be summarized rather than printed in full.

# %%
import pandas as pd

validated_preview = [
  {
    "item_id": "71ca3b660b0ed10f89b4ff4548b5e12e2c3d9d98068d5d9bbdae5d5e6288cf29",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Fuel costs for low-income workers could rise by \u20ac1,000: CPB",
    "source": "dutchnews.nl",
    "url": "https://www.dutchnews.nl/2026/04/fuel-costs-for-low-income-workers-could-rise-by-e1000-cpb",
    "summary": "Fuel costs for low-income workers could rise by \u20ac1,000: CPB. April 16, 2026 Photo: DutchNews.nl. Any political support to cushion the current",
    "classification": "news",
    "published_date": "[REDACTED_PHONE]",
    "location_hint": "Netherlands",
    "category": "economy",
    "content_type": "article",
    "family_friendly": false,
    "technical_level": "basic",
    "source_tier": "tier1",
    "date_confidence": 0.8,
    "is_listing_page": false,
    "validation_flags": [
      "date_source:content_date",
      "stale_risk:medium",
      "age_days:6"
    ],
    "age_days": 6,
    "_truncated_keys": 2
  },
  {
    "item_id": "536673ec3a95230acb7a2c948d609e96937ff45a0c1a2bdd4722e1e65ab88f28",
    "domain": "events",
    "track_type": "events",
    "beat": "events",
    "title": "Maastricht in 2026 | Concerts, Festivals, Tickets & Tour Dates",
    "source": "songkick.com",
    "url": "https://www.songkick.com/metro-areas/31398-netherlands-maastricht/2026",
    "summary": "Muziekgieterij, Maastricht, Netherlands. Saturday 25 April 2026. Yong Yello Concert Tickets - 2026 Tour Dates \u00b7 Yong Yello \u00b7 Muziekgieterij, Maastricht,",
    "classification": "event",
    "published_date": "[REDACTED_PHONE]",
    "location_hint": "Maastricht",
    "category": "events",
    "content_type": "event",
    "family_friendly": false,
    "technical_level": "basic",
    "source_tier": "unknown",
    "date_confidence": 0.8,
    "is_listing_page": false,
    "validation_flags": [
      "date_source:content_date",
      "stale_risk:low",
      "age_days:-3",
      "unknown_tier"
    ],
    "age_days": -3,
    "_truncated_keys": 2
  },
  {
    "item_id": "b6490aaf40dc74626f5d60ffa21496cc462df63bd608ff94938006c39760c9bc",
    "domain": "bitcoin",
    "track_type": "bitcoin",
    "beat": "bitcoin",
    "title": "v30.0 Testing \u00b7 Issue #33368 \u00b7 bitcoin/bitcoin - GitHub",
    "source": "github.com",
    "url": "https://github.com/bitcoin/bitcoin/issues/33368",
    "summary": "Upgraded bitcoind from version 29.0 to 30.0rc1. Bitcoind (30.0rc1) is working great (txindex=1) with low block verification times (about 1",
    "classification": "analysis",
    "published_date": "[REDACTED_PHONE]",
    "location_hint": "",
    "category": "technical",
    "content_type": "technical",
    "family_friendly": false,
    "technical_level": "advanced",
    "source_tier": "tier1",
    "date_confidence": 0.3,
    "is_listing_page": false,
    "validation_flags": [
      "date_source:technical_inferred_today",
      "stale_risk:high",
      "age_days:0"
    ],
    "age_days": 0,
    "_truncated_keys": 2
  },
  {
    "item_id": "6b5e305a93d12191e948d4a27ab7736ef9b338ad067bc465da0e76d4ddce23b9",
    "domain": "bitcoin",
    "track_type": "bitcoin",
    "beat": "bitcoin",
    "title": "Mining interface tracking issue #33777 - bitcoin/bitcoin - GitHub",
    "source": "github.com",
    "url": "https://github.com/bitcoin/bitcoin/issues/33777",
    "summary": "These are bug fixes, not new features. Except for #34568 (already merged) they are not breaking changes, so they if they don't make it into v31.",
    "classification": "analysis",
    "published_date": "[REDACTED_PHONE]",
    "location_hint": "",
    "category": "technical",
    "content_type": "technical",
    "family_friendly": false,
    "technical_level": "advanced",
    "source_tier": "tier1",
    "date_confidence": 0.65,
    "is_listing_page": false,
    "validation_flags": [
      "date_source:relative_today",
      "stale_risk:low",
      "age_days:0"
    ],
    "age_days": 0,
    "_truncated_keys": 2
  }
]
rejected_preview = [
  {
    "item_id": "744df85302a4d36aa84910539e517ef8bdd4e20ecb52ff89341f2c6198d39c9e",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Netherlands declines to follow German example of fuel tax cuts",
    "source": "nltimes.nl",
    "url": "https://nltimes.nl/2026/04/14/netherlands-declines-follow-german-example-fuel-tax-cuts",
    "reason": "not_recent",
    "reason_detail": "date_source=published_or_url_date",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "d7ee61ce3d0d590eb267912ccfa595d7c99e9d0c11710c84ac7239483b448531",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Government will collect more income tax in 2026; Deficit not as bad ...",
    "source": "nltimes.nl",
    "url": "https://nltimes.nl/2025/04/18/government-will-collect-income-tax-2026-deficit-bad-anticipated",
    "reason": "not_recent",
    "reason_detail": "date_source=published_or_url_date",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "3eb4c2ab84c771491bcc93f40915db55f9323356473f64ccc0b664dbc40e2405",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Dutch economy \"can take a hit,\" ABN Amro says - NL Times",
    "source": "nltimes.nl",
    "url": "https://nltimes.nl/2026/03/25/dutch-economy-can-take-hit-abn-amro-says",
    "reason": "not_recent",
    "reason_detail": "date_source=published_or_url_date",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "733e0dbde119a4b70bbfd7aeadc44cdbfa7c6ecf79f6ef201fe2a058b86c0bd7",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Dutch labor talks resume after strikes halt parliament work, shut ...",
    "source": "nltimes.nl",
    "url": "https://nltimes.nl/2026/04/18/dutch-labor-talks-resume-strikes-halt-parliament-work-shut-slaughterhouses",
    "reason": "not_article_page",
    "reason_detail": "validator=Publication date is future (2026), which undermines credibility and currency; content may not be factual or relevant for current research.",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "c6f71485cd272c4d50245614e9946e86fa378688a15bd11b39f0d9832a657f8b",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Civil servants to strike Tuesday, affecting gov't services, cleaning ...",
    "source": "nltimes.nl",
    "url": "https://nltimes.nl/2026/04/10/civil-servants-strike-tuesday-affecting-govt-services-cleaning-slaughterhouses",
    "reason": "not_recent",
    "reason_detail": "date_source=published_or_url_date",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "f52b86cf84d706de4d76d7bfca4b74ff43c28e04f2164f7b73ca30e5872880d3",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "112 - L1 Nieuws",
    "source": "1limburg.nl",
    "url": "https://www.1limburg.nl/112",
    "reason": "not_article_page",
    "reason_detail": "news_static_page",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "34c7bf3378a005f3b6465964526125389ce0a03c575ab01e630687093337e4d9",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "112 - L1 Nieuws",
    "source": "1limburg.nl",
    "url": "http://1limburg.nl/112",
    "reason": "not_article_page",
    "reason_detail": "news_static_page",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "a992c687bb1279bab800ac7386f4b8e5ec157c74455341b9e8e71f7f4187fc3a",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "'Draaiboek huldiging Verstappen in Maastricht ligt klaar' - L1 Nieuws",
    "source": "1limburg.nl",
    "url": "https://www.1limburg.nl/draaiboek-huldiging-verstappen-maastricht-ligt-klaar",
    "reason": "not_recent",
    "reason_detail": "date_source=content_date",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "25839f22de0a14540a719f21e6c156497ba6c5fed7ad2f7cffba3e5c0329cff3",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Maastrichtse dirigent Peter Serpenti overleden - L1 Nieuws",
    "source": "1limburg.nl",
    "url": "https://www.1limburg.nl/maastrichtse-dirigent-peter-serpenti-overleden",
    "reason": "not_recent",
    "reason_detail": "date_source=content_date",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  },
  {
    "item_id": "cfef719da34ec0f729b59f31146e57de2dad21a5199ae56c449fed74f99bd205",
    "domain": "news",
    "track_type": "news",
    "beat": "news",
    "title": "Cultuur & Media - L1 Nieuws",
    "source": "1limburg.nl",
    "url": "https://www.1limburg.nl/cultuur-en-media",
    "reason": "not_recent",
    "reason_detail": "date_source=missing",
    "content_type": "article",
    "url_pattern_match": "",
    "title_alignment": true,
    "stage": "validator"
  }
]
validated_df = pd.DataFrame(validated_preview)
rejected_df = pd.DataFrame(rejected_preview)
display(validated_df.head())
display(rejected_df.head())

# %%
import matplotlib.pyplot as plt
import pandas as pd

reason_counts = {
  "altcoin_noise": 1,
  "duplicate_in_run": 5,
  "generic_listing": 7,
  "low_trust_source": 3,
  "missing_specific_date": 2,
  "not_article_page": 5,
  "not_recent": 13
}
selected_counts = {
  "bitcoin": 1,
  "events": 1,
  "news": 1
}
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
reason_series = pd.to_numeric(pd.Series(reason_counts), errors='coerce').dropna()
selected_series = pd.to_numeric(pd.Series(selected_counts), errors='coerce').dropna()

if reason_series.empty:
    axes[0].set_title('Rejection reasons')
    axes[0].text(0.5, 0.5, 'No rejection reasons', ha='center', va='center')
    axes[0].set_xlabel('Count')
    axes[0].set_yticks([])
else:
    reason_series.sort_values().plot(kind='barh', ax=axes[0], title='Rejection reasons')
    axes[0].set_xlabel('Count')

if selected_series.empty:
    axes[1].set_title('Selected counts')
    axes[1].text(0.5, 0.5, 'No selected items', ha='center', va='center')
    axes[1].set_xlabel('Count')
    axes[1].set_yticks([])
else:
    selected_series.sort_values().plot(kind='barh', ax=axes[1], title='Selected counts')
    axes[1].set_xlabel('Count')
plt.tight_layout()

# %% [markdown]
# ## Conclusion
#
# The run processed 40 candidates and selected 3 final items. The quality gate status was `warn`. Review warning and rejection reason sections before using this run as a demo sample.

# %% [markdown]
# ## Future Work
#
# - Compare this run with the next v3 run after Telegram-triggered execution.
# - Track repeated rejection reasons in the database feedback tables.
# - Add richer plots only when they answer a concrete validation question.

# %% [markdown]
# ## Style Reference
#
# # Notebook Style Guide
#
# Generated Personal Research Agent v3 notebooks should read like a concise test report.
#
# ## Structure
#
# 1. Title with the run ID or debug folder name.
# 2. Introduction explaining the purpose of the run.
# 3. Setup with the project path, debug directory, and reproducibility notes.
# 4. Data overview with input, candidate counts, validation counts, and selected counts.
# 5. Execution showing how the debug artifacts can be loaded.
# 6. Analysis with tables and simple charts for rejection reasons and selected categories.
# 7. Conclusion with pass/fail interpretation and notable anomalies.
# 8. Future work with concrete next checks or directives.
#
# ## Tone
#
# Use brief factual English. Prefer short paragraphs, explicit counts, and neutral observations. Avoid conversational filler inside generated notebooks.
#
# ## Code Cells
#
# Code cells should be runnable after installing project requirements. Keep them small and transparent. Use pandas for tables and Matplotlib for simple bar charts.
